# %% [markdown]
# # Loading the data and packages

# %%
import pandas as pd
import numpy as np
#Loading the data
data= pd.read_csv('EnquiryTotal.csv')

# %% [markdown]
# # List all column names

# %%
data.columns.tolist()
# Out:
# ['Enquiry.Date',
#  'Enquiry.Time',
#  'Enquiry.Day',
#  'Allocated.Time',
#  'Web.or.Phone',
#  'Hotkey.',
#  'Number.of.Conversation.RCD',
#  'Number.of.Quote.Templates.Sent.to.client',
#  'Holiday.Type',
#  'Accommodation.type',
#  'Departure.Airport',
#  'DepartureDate',
#  'Lead.Time..weeks.',
#  'Destination.1',
#  'Duration',
#  'Adults',
#  'Children',
#  'Infants',
#  'Transport.Type',
#  'Answered.Questionnaire.',
#  'Questionnaire.Notes.Completed',
#  'Title',
#  'Any.Enquiry.Comments.',
#  'Booked.Status']

# %% [markdown]
# # Rename column names

# %%
data.columns = ['Date',
 'EnquiryTime',
 'EnquiryDay',
 'AllocatedTime',
 'WeborPhone',
 'Hotkey',
 'NumberofConversationRCD',
 'TemplatesSent',
 'HolidayType',
 'Accommodationtype',
 'DepartureAirport',
 'DepartureDate',
 'Lead.Timeweeks.',
 'Destination1',
 'Duration',
 'Adults',
 'Children',
 'Infants',
 'TransportType',
 'Answered.Questionnaire',
 'NotesCompleted',
 'Title',
 'Any.Enquiry.Comments',
 'BookedStatus']

# %% [markdown]
# # View first 10 rows (Data.tail for last)

# %%
data.head(10)
# Out:
#          Date EnquiryTime EnquiryDay AllocatedTime WeborPhone   Hotkey  \
# 0   5/18/2018        9:00     Friday    3d 2h 46m         WEB      NaN
# 1   2/18/2018       19:46     Sunday    1d 0h 20m         WEB      NaN
# 2    1/5/2018       23:38     Friday   2d 22h 13m         WEB      NaN
# 3   1/30/2019       20:21  Wednesday   0d 12h 56m         WEB  Hot Key
# 4   1/26/2019       12:42   Saturday     0d 0h 3m         WEB  Hot Key
# 5   1/22/2019       12:19    Tuesday     0d 0h 2m         WEB  Hot Key
# 6   1/12/2019       20:13   Saturday   0d 16h 10m         WEB  Hot Key
# 7    1/2/2019       17:09  Wednesday     0d 0h 2m         WEB  Hot Key
# 8  12/27/2018       15:39   Thursday     0d 0h 2m         WEB  Hot Key
# 9  12/26/2018       21:08  Wednesday   1d 21h 44m         WEB  Hot Key
#
#    NumberofConversationRCD  TemplatesSent         HolidayType  \
# 0                        0              1       Cruise + Stay
# 1                        0              1  Accommodation Only
# 2                        0              1     Package Holiday
# 3                        1              1        Multi Centre
# 4                        3              3     Package Holiday
# 5                        3              2     Package Holiday
# 6                        3              2     Package Holiday
# 7                        1              1        Multi Centre
# 8                        0              1     Package Holiday
# 9                        0              1     Package Holiday
#
#   Accommodationtype  ... Duration Adults  Children Infants     TransportType  \
# 0             Hotel  ...      7.0      2         0       0  Return transfers
# 1             Villa  ...      7.0      3         2       0  Return transfers
# 2             Villa  ...      6.0      4         0       0  Return transfers
# 3               NaN  ...     10.0      4         0       0  Return transfers
# 4             Hotel  ...     10.0      3         3       0  Return transfers
# 5             Hotel  ...     10.0      2         2       0  Return transfers
# 6             Hotel  ...     14.0      2         2       0  Return transfers
# 7               NaN  ...     14.0      2         2       0  Return transfers
# 8             Villa  ...     10.0      2         3       0  Return transfers
# 9             Hotel  ...      7.0      2         1       1  Return transfers
#
#    Answered.Questionnaire  NotesCompleted  Title Any.Enquiry.Comments  \
# 0                      NO              NO     Mr                   NO
# 1                      NO              NO     Mr                   NO
# 2                     YES             YES     Mr                   NO
# 3                     YES             YES     Dr                   NO
# 4                      NO              NO     Dr                  YES
# 5                      NO              NO     Dr                  YES
# 6                     YES              NO     Dr                   NO
# 7                     YES             YES     Dr                   NO
# 8                      NO              NO     Dr                   NO
# 9                     YES              NO     Dr                   NO
#
#   BookedStatus
# 0           NO
# 1           NO
# 2           NO
# 3           NO
# 4           NO
# 5          YES
# 6           NO
# 7           NO
# 8           NO
# 9           NO
#
# [10 rows x 24 columns]

# %% [markdown]
# # Check data type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178347 entries, 0 to 178346
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Date                     178347 non-null  object
#  1   EnquiryTime              178347 non-null  object
#  2   EnquiryDay               178347 non-null  object
#  3   AllocatedTime            165064 non-null  object
#  4   WeborPhone               178347 non-null  object
#  5   Hotkey                   49251 non-null   object
#  6   NumberofConversationRCD  178347 non-null  int64
#  7   TemplatesSent            178347 non-null  int64
#  8   HolidayType              178347 non-null  object
#  9   Accommodationtype        165740 non-null  object
#  10  DepartureAirport         178199 non-null  object
#  11  DepartureDate            178347 non-null  object
#  12  Lead.Timeweeks.          178347 non-null  int64
#  13  Destination1             178322 non-null  object
#  14  Duration                 178322 non-null  float64
#  15  Adults                   178347 non-null  int64
#  16  Children                 178347 non-null  int64
#  17  Infants                  178347 non-null  int64
#  18  TransportType            172508 non-null  object
#  19  Answered.Questionnaire   178347 non-null  object
#  20  NotesCompleted           178347 non-null  object
#  21  Title                    178347 non-null  object
#  22  Any.Enquiry.Comments     178347 non-null  object
#  23  BookedStatus             178347 non-null  object
# dtypes: float64(1), int64(6), object(17)
# memory usage: 32.7+ MB

# %% [markdown]
# # Change data type

# %%
data.Adults=data.Adults.astype(int)

# %% [markdown]
# # Sorting Data

# %%
data.sort_values(['EnquiryDay','WeborPhone'],ascending=[1,0])
# Out:
#              Date EnquiryTime EnquiryDay AllocatedTime WeborPhone   Hotkey  \
# 0       5/18/2018        9:00     Friday    3d 2h 46m         WEB      NaN
# 2        1/5/2018       23:38     Friday   2d 22h 13m         WEB      NaN
# 12      9/14/2018       23:08     Friday    0d 15h 3m         WEB  Hot Key
# 19      4/13/2018       22:14     Friday   0d 12h 26m         WEB  Hot Key
# 28       1/4/2019       10:14     Friday   2d 23h 32m         WEB      NaN
# ...           ...         ...        ...           ...        ...      ...
# 178338  8/16/2017    12:56:40  Wednesday   49d 2h 28m       PHONE      NaN
# 178339  8/16/2017    12:55:42  Wednesday           0 m      PHONE      NaN
# 178340  8/16/2017    13:18:47  Wednesday  18d 20h 37m       PHONE      NaN
# 178341  8/16/2017    19:17:57  Wednesday  18d 14h 38m       PHONE      NaN
# 178342  8/16/2017    16:12:04  Wednesday           0 m      PHONE      NaN
#
#         NumberofConversationRCD  TemplatesSent      HolidayType  \
# 0                             0              1    Cruise + Stay
# 2                             0              1  Package Holiday
# 12                            6              5     Multi Centre
# 19                            1              1  Package Holiday
# 28                            0              1  Package Holiday
# ...                         ...            ...              ...
# 178338                        2              1  Package Holiday
# 178339                        0              1  Package Holiday
# 178340                        0              1  Package Holiday
# 178341                       10              1     Multi Centre
# 178342                        6              3    Cruise + Stay
#
#        Accommodationtype  ... Duration Adults  Children Infants  \
# 0                  Hotel  ...      7.0      2         0       0
# 2                  Villa  ...      6.0      4         0       0
# 12                 Hotel  ...     14.0      4         0       0
# 19                 Hotel  ...     14.0      3         1       0
# 28                 Hotel  ...     14.0      2         0       0
# ...                  ...  ...      ...    ...       ...     ...
# 178338             Hotel  ...     14.0      4         0       0
# 178339             Hotel  ...     14.0      2         3       0
# 178340              None  ...     14.0     10         0       0
# 178341             Hotel  ...      7.0      2         0       0
# 178342             Hotel  ...     14.0      2         0       0
#
#            TransportType  Answered.Questionnaire  NotesCompleted  Title  \
# 0       Return transfers                      NO              NO     Mr
# 2       Return transfers                     YES             YES     Mr
# 12      Return transfers                     YES              NO     Dr
# 19      Return transfers                     YES             YES     Dr
# 28      Return transfers                     YES              NO     Dr
# ...                  ...                     ...             ...    ...
# 178338               NaN                      NO              NO     Mr
# 178339               NaN                      NO              NO     Mr
# 178340               NaN                      NO              NO     Mr
# 178341               NaN                      NO              NO     Mr
# 178342               NaN                      NO              NO     Mr
#
#        Any.Enquiry.Comments BookedStatus
# 0                        NO           NO
# 2                        NO           NO
# 12                      YES           NO
# 19                       NO          YES
# 28                       NO           NO
# ...                     ...          ...
# 178338                   NO           NO
# 178339                   NO           NO
# 178340                   NO           NO
# 178341                   NO           NO
# 178342                   NO           NO
#
# [178347 rows x 24 columns]

# %% [markdown]
# # Select all except 1 field

# %%
data.loc[:, data.columns != 'Infants']
# Out:
#              Date EnquiryTime EnquiryDay AllocatedTime WeborPhone   Hotkey  \
# 0       5/18/2018        9:00     Friday    3d 2h 46m         WEB      NaN
# 1       2/18/2018       19:46     Sunday    1d 0h 20m         WEB      NaN
# 2        1/5/2018       23:38     Friday   2d 22h 13m         WEB      NaN
# 3       1/30/2019       20:21  Wednesday   0d 12h 56m         WEB  Hot Key
# 4       1/26/2019       12:42   Saturday     0d 0h 3m         WEB  Hot Key
# ...           ...         ...        ...           ...        ...      ...
# 178342  8/16/2017    16:12:04  Wednesday           0 m      PHONE      NaN
# 178343  8/15/2017    12:11:38    Tuesday    2d 21h 9m       PHONE      NaN
# 178344  8/15/2017    11:32:24    Tuesday    6d 6h 46m       PHONE      NaN
# 178345  8/15/2017    11:21:27    Tuesday   6d 23h 13m       PHONE      NaN
# 178346  8/15/2017    11:51:10    Tuesday   3d 23h 44m         WEB      NaN
#
#         NumberofConversationRCD  TemplatesSent         HolidayType  \
# 0                             0              1       Cruise + Stay
# 1                             0              1  Accommodation Only
# 2                             0              1     Package Holiday
# 3                             1              1        Multi Centre
# 4                             3              3     Package Holiday
# ...                         ...            ...                 ...
# 178342                        6              3       Cruise + Stay
# 178343                        0              0     Package Holiday
# 178344                        0              1     Package Holiday
# 178345                        0              1     Package Holiday
# 178346                        0              0  Accommodation Only
#
#        Accommodationtype  ...               Destination1 Duration  Adults  \
# 0                  Hotel  ...                     MEXICO      7.0       2
# 1                  Villa  ...                    Orlando      7.0       3
# 2                  Villa  ...                    FLORIDA      6.0       4
# 3                    NaN  ...                Los Angeles     10.0       4
# 4                  Hotel  ...   Walt Disney World Resort     10.0       3
# ...                  ...  ...                        ...      ...     ...
# 178342             Hotel  ...                    FLORIDA     14.0       2
# 178343             Villa  ...                    FLORIDA     14.0       2
# 178344             Hotel  ...   Walt Disney World Resort     10.0       2
# 178345              None  ...                  CARIBBEAN     14.0       2
# 178346             Hotel  ...                    FLORIDA     14.0       1
#
#        Children     TransportType  Answered.Questionnaire  NotesCompleted  \
# 0             0  Return transfers                      NO              NO
# 1             2  Return transfers                      NO              NO
# 2             0  Return transfers                     YES             YES
# 3             0  Return transfers                     YES             YES
# 4             3  Return transfers                      NO              NO
# ...         ...               ...                     ...             ...
# 178342        0               NaN                      NO              NO
# 178343        0               NaN                      NO              NO
# 178344        0               NaN                      NO              NO
# 178345        0               NaN                      NO              NO
# 178346        0               NaN                      NO              NO
#
#        Title Any.Enquiry.Comments BookedStatus
# 0         Mr                   NO           NO
# 1         Mr                   NO           NO
# 2         Mr                   NO           NO
# 3         Dr                   NO           NO
# 4         Dr                  YES           NO
# ...      ...                  ...          ...
# 178342    Mr                   NO           NO
# 178343    Mr                   NO           NO
# 178344    Mr                   NO           NO
# 178345    Mr                   NO           NO
# 178346    Mr                   NO           NO
#
# [178347 rows x 23 columns]

# %% [markdown]
# # Drop multiple columns

# %%
data.loc[:, ~data.columns.isin(['Infants', 'Children'])]
# Out:
#              Date EnquiryTime EnquiryDay AllocatedTime WeborPhone   Hotkey  \
# 0       5/18/2018        9:00     Friday    3d 2h 46m         WEB      NaN
# 1       2/18/2018       19:46     Sunday    1d 0h 20m         WEB      NaN
# 2        1/5/2018       23:38     Friday   2d 22h 13m         WEB      NaN
# 3       1/30/2019       20:21  Wednesday   0d 12h 56m         WEB  Hot Key
# 4       1/26/2019       12:42   Saturday     0d 0h 3m         WEB  Hot Key
# ...           ...         ...        ...           ...        ...      ...
# 178342  8/16/2017    16:12:04  Wednesday           0 m      PHONE      NaN
# 178343  8/15/2017    12:11:38    Tuesday    2d 21h 9m       PHONE      NaN
# 178344  8/15/2017    11:32:24    Tuesday    6d 6h 46m       PHONE      NaN
# 178345  8/15/2017    11:21:27    Tuesday   6d 23h 13m       PHONE      NaN
# 178346  8/15/2017    11:51:10    Tuesday   3d 23h 44m         WEB      NaN
#
#         NumberofConversationRCD  TemplatesSent         HolidayType  \
# 0                             0              1       Cruise + Stay
# 1                             0              1  Accommodation Only
# 2                             0              1     Package Holiday
# 3                             1              1        Multi Centre
# 4                             3              3     Package Holiday
# ...                         ...            ...                 ...
# 178342                        6              3       Cruise + Stay
# 178343                        0              0     Package Holiday
# 178344                        0              1     Package Holiday
# 178345                        0              1     Package Holiday
# 178346                        0              0  Accommodation Only
#
#        Accommodationtype  ... Lead.Timeweeks.               Destination1  \
# 0                  Hotel  ...              30                     MEXICO
# 1                  Villa  ...              34                    Orlando
# 2                  Villa  ...              33                    FLORIDA
# 3                    NaN  ...              28                Los Angeles
# 4                  Hotel  ...              76   Walt Disney World Resort
# ...                  ...  ...             ...                        ...
# 178342             Hotel  ...               0                    FLORIDA
# 178343             Villa  ...             115                    FLORIDA
# 178344             Hotel  ...              50   Walt Disney World Resort
# 178345              None  ...              46                  CARIBBEAN
# 178346             Hotel  ...               0                    FLORIDA
#
#         Duration Adults     TransportType  Answered.Questionnaire  \
# 0            7.0      2  Return transfers                      NO
# 1            7.0      3  Return transfers                      NO
# 2            6.0      4  Return transfers                     YES
# 3           10.0      4  Return transfers                     YES
# 4           10.0      3  Return transfers                      NO
# ...          ...    ...               ...                     ...
# 178342      14.0      2               NaN                      NO
# 178343      14.0      2               NaN                      NO
# 178344      10.0      2               NaN                      NO
# 178345      14.0      2               NaN                      NO
# 178346      14.0      1               NaN                      NO
#
#        NotesCompleted Title Any.Enquiry.Comments BookedStatus
# 0                  NO    Mr                   NO           NO
# 1                  NO    Mr                   NO           NO
# 2                 YES    Mr                   NO           NO
# 3                 YES    Dr                   NO           NO
# 4                  NO    Dr                  YES           NO
# ...               ...   ...                  ...          ...
# 178342             NO    Mr                   NO           NO
# 178343             NO    Mr                   NO           NO
# 178344             NO    Mr                   NO           NO
# 178345             NO    Mr                   NO           NO
# 178346             NO    Mr                   NO           NO
#
# [178347 rows x 22 columns]

# %% [markdown]
# # Select multiple columns

# %%
data.iloc[:,[0,1,4]]
# Out:
#              Date EnquiryTime WeborPhone
# 0       5/18/2018        9:00        WEB
# 1       2/18/2018       19:46        WEB
# 2        1/5/2018       23:38        WEB
# 3       1/30/2019       20:21        WEB
# 4       1/26/2019       12:42        WEB
# ...           ...         ...        ...
# 178342  8/16/2017    16:12:04      PHONE
# 178343  8/15/2017    12:11:38      PHONE
# 178344  8/15/2017    11:32:24      PHONE
# 178345  8/15/2017    11:21:27      PHONE
# 178346  8/15/2017    11:51:10        WEB
#
# [178347 rows x 3 columns]

# %% [markdown]
# # Select columns 0 to 2

# %%
data.iloc[:, 0:2]
# Out:
#              Date EnquiryTime
# 0       5/18/2018        9:00
# 1       2/18/2018       19:46
# 2        1/5/2018       23:38
# 3       1/30/2019       20:21
# 4       1/26/2019       12:42
# ...           ...         ...
# 178342  8/16/2017    16:12:04
# 178343  8/15/2017    12:11:38
# 178344  8/15/2017    11:32:24
# 178345  8/15/2017    11:21:27
# 178346  8/15/2017    11:51:10
#
# [178347 rows x 2 columns]

# %% [markdown]
# # Selecting multiple required columns

# %%
data.iloc[:, np.r_[0:3,15:19,22,23]]
# Out:
#              Date EnquiryTime EnquiryDay  Adults  Children  Infants  \
# 0       5/18/2018        9:00     Friday       2         0        0
# 1       2/18/2018       19:46     Sunday       3         2        0
# 2        1/5/2018       23:38     Friday       4         0        0
# 3       1/30/2019       20:21  Wednesday       4         0        0
# 4       1/26/2019       12:42   Saturday       3         3        0
# ...           ...         ...        ...     ...       ...      ...
# 178342  8/16/2017    16:12:04  Wednesday       2         0        0
# 178343  8/15/2017    12:11:38    Tuesday       2         0        0
# 178344  8/15/2017    11:32:24    Tuesday       2         0        0
# 178345  8/15/2017    11:21:27    Tuesday       2         0        0
# 178346  8/15/2017    11:51:10    Tuesday       1         0        0
#
#            TransportType Any.Enquiry.Comments BookedStatus
# 0       Return transfers                   NO           NO
# 1       Return transfers                   NO           NO
# 2       Return transfers                   NO           NO
# 3       Return transfers                   NO           NO
# 4       Return transfers                  YES           NO
# ...                  ...                  ...          ...
# 178342               NaN                   NO           NO
# 178343               NaN                   NO           NO
# 178344               NaN                   NO           NO
# 178345               NaN                   NO           NO
# 178346               NaN                   NO           NO
#
# [178347 rows x 9 columns]

# %% [markdown]
# # Select columns which have enquiry in the name

# %%
data.filter(like='Enquiry')
# Out:
#        EnquiryTime EnquiryDay Any.Enquiry.Comments
# 0             9:00     Friday                   NO
# 1            19:46     Sunday                   NO
# 2            23:38     Friday                   NO
# 3            20:21  Wednesday                   NO
# 4            12:42   Saturday                  YES
# ...            ...        ...                  ...
# 178342    16:12:04  Wednesday                   NO
# 178343    12:11:38    Tuesday                   NO
# 178344    11:32:24    Tuesday                   NO
# 178345    11:21:27    Tuesday                   NO
# 178346    11:51:10    Tuesday                   NO
#
# [178347 rows x 3 columns]

# %% [markdown]
# # Select columns based on multiple patterns

# %%
data.filter(regex='Type|Enquiry')
# Out:
#        EnquiryTime EnquiryDay         HolidayType     TransportType  \
# 0             9:00     Friday       Cruise + Stay  Return transfers
# 1            19:46     Sunday  Accommodation Only  Return transfers
# 2            23:38     Friday     Package Holiday  Return transfers
# 3            20:21  Wednesday        Multi Centre  Return transfers
# 4            12:42   Saturday     Package Holiday  Return transfers
# ...            ...        ...                 ...               ...
# 178342    16:12:04  Wednesday       Cruise + Stay               NaN
# 178343    12:11:38    Tuesday     Package Holiday               NaN
# 178344    11:32:24    Tuesday     Package Holiday               NaN
# 178345    11:21:27    Tuesday     Package Holiday               NaN
# 178346    11:51:10    Tuesday  Accommodation Only               NaN
#
#        Any.Enquiry.Comments
# 0                        NO
# 1                        NO
# 2                        NO
# 3                        NO
# 4                       YES
# ...                     ...
# 178342                   NO
# 178343                   NO
# 178344                   NO
# 178345                   NO
# 178346                   NO
#
# [178347 rows x 5 columns]

# %% [markdown]
# # Remove columns

# %%
data = data.drop(["EnquiryTime", "AllocatedTime"],axis=1)

# %% [markdown]
# # Check data type

# %%
print(data.dtypes)
# Out:
# Date                        object
# EnquiryDay                  object
# WeborPhone                  object
# Hotkey                      object
# NumberofConversationRCD      int64
# TemplatesSent                int64
# HolidayType                 object
# Accommodationtype           object
# DepartureAirport            object
# DepartureDate               object
# Lead.Timeweeks.              int64
# Destination1                object
# Duration                   float64
# Adults                       int32
# Children                     int64
# Infants                      int64
# TransportType               object
# Answered.Questionnaire      object
# NotesCompleted              object
# Title                       object
# Any.Enquiry.Comments        object
# BookedStatus                object
# dtype: object

# %% [markdown]
# # Change date to date format and extract year and month

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['year'], data['month'] = data['Date'].dt.year, data['Date'].dt.month
# Remove date
data = data.drop(['Date'],axis=1)
data
# Out:
#        EnquiryDay WeborPhone   Hotkey  NumberofConversationRCD  TemplatesSent  \
# 0          Friday        WEB      NaN                        0              1
# 1          Sunday        WEB      NaN                        0              1
# 2          Friday        WEB      NaN                        0              1
# 3       Wednesday        WEB  Hot Key                        1              1
# 4        Saturday        WEB  Hot Key                        3              3
# ...           ...        ...      ...                      ...            ...
# 178342  Wednesday      PHONE      NaN                        6              3
# 178343    Tuesday      PHONE      NaN                        0              0
# 178344    Tuesday      PHONE      NaN                        0              1
# 178345    Tuesday      PHONE      NaN                        0              1
# 178346    Tuesday        WEB      NaN                        0              0
#
#                HolidayType Accommodationtype DepartureAirport DepartureDate  \
# 0            Cruise + Stay             Hotel       Birmingham    12/14/2018
# 1       Accommodation Only             Villa       London All    10/19/2018
# 2          Package Holiday             Villa        Edinburgh     8/19/2018
# 3             Multi Centre               NaN       Manchester     8/11/2019
# 4          Package Holiday             Hotel          Belfast     7/11/2020
# ...                    ...               ...              ...           ...
# 178342       Cruise + Stay             Hotel       London All     8/16/2017
# 178343     Package Holiday             Villa       Manchester    10/27/2019
# 178344     Package Holiday             Hotel   London Gatwick      8/1/2018
# 178345     Package Holiday              None          Glasgow      7/2/2018
# 178346  Accommodation Only             Hotel      Any Airport     8/15/2017
#
#         Lead.Timeweeks.  ... Children  Infants     TransportType  \
# 0                    30  ...        0        0  Return transfers
# 1                    34  ...        2        0  Return transfers
# 2                    33  ...        0        0  Return transfers
# 3                    28  ...        0        0  Return transfers
# 4                    76  ...        3        0  Return transfers
# ...                 ...  ...      ...      ...               ...
# 178342                0  ...        0        0               NaN
# 178343              115  ...        0        0               NaN
# 178344               50  ...        0        0               NaN
# 178345               46  ...        0        0               NaN
# 178346                0  ...        0        0               NaN
#
#         Answered.Questionnaire  NotesCompleted Title Any.Enquiry.Comments  \
# 0                           NO              NO    Mr                   NO
# 1                           NO              NO    Mr                   NO
# 2                          YES             YES    Mr                   NO
# 3                          YES             YES    Dr                   NO
# 4                           NO              NO    Dr                  YES
# ...                        ...             ...   ...                  ...
# 178342                      NO              NO    Mr                   NO
# 178343                      NO              NO    Mr                   NO
# 178344                      NO              NO    Mr                   NO
# 178345                      NO              NO    Mr                   NO
# 178346                      NO              NO    Mr                   NO
#
#        BookedStatus  year month
# 0                NO  2018     5
# 1                NO  2018     2
# 2                NO  2018     1
# 3                NO  2019     1
# 4                NO  2019     1
# ...             ...   ...   ...
# 178342           NO  2017     8
# 178343           NO  2017     8
# 178344           NO  2017     8
# 178345           NO  2017     8
# 178346           NO  2017     8
#
# [178347 rows x 23 columns]

# %% [markdown]
# # Understand numerical variables

# %%
data.describe()
# Out:
#        NumberofConversationRCD  TemplatesSent  Lead.Timeweeks.       Duration  \
# count            178347.000000  178347.000000    178347.000000  178322.000000
# mean                  1.259489       1.341295        50.094445      13.106448
# std                   2.960769       1.147345        27.735302       3.630358
# min                   0.000000       0.000000       -44.000000       0.000000
# 25%                   0.000000       1.000000        29.000000      11.000000
# 50%                   0.000000       1.000000        48.000000      14.000000
# 75%                   1.000000       1.000000        68.000000      14.000000
# max                 356.000000      29.000000       216.000000      63.000000
#
#               Adults       Children        Infants           year  \
# count  178347.000000  178347.000000  178347.000000  178347.000000
# mean        3.439301       1.047161       0.061571    2017.586256
# std         2.030107       1.237065       0.674152       0.602170
# min         1.000000       0.000000       0.000000    2017.000000
# 25%         2.000000       0.000000       0.000000    2017.000000
# 50%         3.000000       1.000000       0.000000    2018.000000
# 75%         4.000000       2.000000       0.000000    2018.000000
# max        58.000000      25.000000     255.000000    2019.000000
#
#                month
# count  178347.000000
# mean        5.922679
# std         3.499919
# min         1.000000
# 25%         3.000000
# 50%         6.000000
# 75%         9.000000
# max        12.000000

# %% [markdown]
# # Understand categorical variables (use include='all' to show both numerical and categorical)

# %%
data.describe(include=[object])
# Out:
#        EnquiryDay WeborPhone   Hotkey      HolidayType Accommodationtype  \
# count      178347     178347    49251           178347            165740
# unique          7          2        1               14                 6
# top        Sunday        WEB  Hot Key  Package Holiday             Hotel
# freq        30865     154890    49251           134230             91055
#
#        DepartureAirport DepartureDate Destination1        TransportType  \
# count            178199        178347       178322               172508
# unique               35          1633          125                    3
# top          Manchester      4/6/2019      FLORIDA  Fully comp car hire
# freq              54203          1461        52618                75870
#
#        Answered.Questionnaire NotesCompleted   Title Any.Enquiry.Comments  \
# count                  178347         178347  178347               178347
# unique                      2              2       5                    2
# top                        NO             NO      Mr                   NO
# freq                   103383         142604   77520               136273
#
#        BookedStatus
# count        178347
# unique            2
# top              NO
# freq         168182

# %% [markdown]
#  # Replacing NAN values

# %%
data["Hotkey"].fillna("No",inplace=True)
data
# Out:
#        EnquiryDay WeborPhone   Hotkey  NumberofConversationRCD  TemplatesSent  \
# 0          Friday        WEB       No                        0              1
# 1          Sunday        WEB       No                        0              1
# 2          Friday        WEB       No                        0              1
# 3       Wednesday        WEB  Hot Key                        1              1
# 4        Saturday        WEB  Hot Key                        3              3
# ...           ...        ...      ...                      ...            ...
# 178342  Wednesday      PHONE       No                        6              3
# 178343    Tuesday      PHONE       No                        0              0
# 178344    Tuesday      PHONE       No                        0              1
# 178345    Tuesday      PHONE       No                        0              1
# 178346    Tuesday        WEB       No                        0              0
#
#                HolidayType Accommodationtype DepartureAirport DepartureDate  \
# 0            Cruise + Stay             Hotel       Birmingham    12/14/2018
# 1       Accommodation Only             Villa       London All    10/19/2018
# 2          Package Holiday             Villa        Edinburgh     8/19/2018
# 3             Multi Centre               NaN       Manchester     8/11/2019
# 4          Package Holiday             Hotel          Belfast     7/11/2020
# ...                    ...               ...              ...           ...
# 178342       Cruise + Stay             Hotel       London All     8/16/2017
# 178343     Package Holiday             Villa       Manchester    10/27/2019
# 178344     Package Holiday             Hotel   London Gatwick      8/1/2018
# 178345     Package Holiday              None          Glasgow      7/2/2018
# 178346  Accommodation Only             Hotel      Any Airport     8/15/2017
#
#         Lead.Timeweeks.  ... Children  Infants     TransportType  \
# 0                    30  ...        0        0  Return transfers
# 1                    34  ...        2        0  Return transfers
# 2                    33  ...        0        0  Return transfers
# 3                    28  ...        0        0  Return transfers
# 4                    76  ...        3        0  Return transfers
# ...                 ...  ...      ...      ...               ...
# 178342                0  ...        0        0               NaN
# 178343              115  ...        0        0               NaN
# 178344               50  ...        0        0               NaN
# 178345               46  ...        0        0               NaN
# 178346                0  ...        0        0               NaN
#
#         Answered.Questionnaire  NotesCompleted Title Any.Enquiry.Comments  \
# 0                           NO              NO    Mr                   NO
# 1                           NO              NO    Mr                   NO
# 2                          YES             YES    Mr                   NO
# 3                          YES             YES    Dr                   NO
# 4                           NO              NO    Dr                  YES
# ...                        ...             ...   ...                  ...
# 178342                      NO              NO    Mr                   NO
# 178343                      NO              NO    Mr                   NO
# 178344                      NO              NO    Mr                   NO
# 178345                      NO              NO    Mr                   NO
# 178346                      NO              NO    Mr                   NO
#
#        BookedStatus  year month
# 0                NO  2018     5
# 1                NO  2018     2
# 2                NO  2018     1
# 3                NO  2019     1
# 4                NO  2019     1
# ...             ...   ...   ...
# 178342           NO  2017     8
# 178343           NO  2017     8
# 178344           NO  2017     8
# 178345           NO  2017     8
# 178346           NO  2017     8
#
# [178347 rows x 23 columns]

# %% [markdown]
# # Checking frequency of variables

# %%
pd.value_counts(data["WeborPhone"])
# Out:
# WEB      154890
# PHONE     23457
# Name: WeborPhone, dtype: int64

# %% [markdown]
# # Replace specific values in a dataframe column

# %%
data.Hotkey = data.Hotkey.replace({"NaN":"No",
                                  "Hot Key":"Yes"})
data
# Out:
#        EnquiryDay WeborPhone Hotkey  NumberofConversationRCD  TemplatesSent  \
# 0          Friday        WEB     No                        0              1
# 1          Sunday        WEB     No                        0              1
# 2          Friday        WEB     No                        0              1
# 3       Wednesday        WEB    Yes                        1              1
# 4        Saturday        WEB    Yes                        3              3
# ...           ...        ...    ...                      ...            ...
# 178342  Wednesday      PHONE     No                        6              3
# 178343    Tuesday      PHONE     No                        0              0
# 178344    Tuesday      PHONE     No                        0              1
# 178345    Tuesday      PHONE     No                        0              1
# 178346    Tuesday        WEB     No                        0              0
#
#                HolidayType Accommodationtype DepartureAirport DepartureDate  \
# 0            Cruise + Stay             Hotel       Birmingham    12/14/2018
# 1       Accommodation Only             Villa       London All    10/19/2018
# 2          Package Holiday             Villa        Edinburgh     8/19/2018
# 3             Multi Centre               NaN       Manchester     8/11/2019
# 4          Package Holiday             Hotel          Belfast     7/11/2020
# ...                    ...               ...              ...           ...
# 178342       Cruise + Stay             Hotel       London All     8/16/2017
# 178343     Package Holiday             Villa       Manchester    10/27/2019
# 178344     Package Holiday             Hotel   London Gatwick      8/1/2018
# 178345     Package Holiday              None          Glasgow      7/2/2018
# 178346  Accommodation Only             Hotel      Any Airport     8/15/2017
#
#         Lead.Timeweeks.  ... Children  Infants     TransportType  \
# 0                    30  ...        0        0  Return transfers
# 1                    34  ...        2        0  Return transfers
# 2                    33  ...        0        0  Return transfers
# 3                    28  ...        0        0  Return transfers
# 4                    76  ...        3        0  Return transfers
# ...                 ...  ...      ...      ...               ...
# 178342                0  ...        0        0               NaN
# 178343              115  ...        0        0               NaN
# 178344               50  ...        0        0               NaN
# 178345               46  ...        0        0               NaN
# 178346                0  ...        0        0               NaN
#
#         Answered.Questionnaire  NotesCompleted Title Any.Enquiry.Comments  \
# 0                           NO              NO    Mr                   NO
# 1                           NO              NO    Mr                   NO
# 2                          YES             YES    Mr                   NO
# 3                          YES             YES    Dr                   NO
# 4                           NO              NO    Dr                  YES
# ...                        ...             ...   ...                  ...
# 178342                      NO              NO    Mr                   NO
# 178343                      NO              NO    Mr                   NO
# 178344                      NO              NO    Mr                   NO
# 178345                      NO              NO    Mr                   NO
# 178346                      NO              NO    Mr                   NO
#
#        BookedStatus  year month
# 0                NO  2018     5
# 1                NO  2018     2
# 2                NO  2018     1
# 3                NO  2019     1
# 4                NO  2019     1
# ...             ...   ...   ...
# 178342           NO  2017     8
# 178343           NO  2017     8
# 178344           NO  2017     8
# 178345           NO  2017     8
# 178346           NO  2017     8
#
# [178347 rows x 23 columns]

# %% [markdown]
# # Conditional changes (if web then hotkey is error)

# %%
data.loc[data['WeborPhone']== "WEB",['Hotkey']] = 'Error'
data
# Out:
#        EnquiryDay WeborPhone Hotkey  NumberofConversationRCD  TemplatesSent  \
# 0          Friday        WEB  Error                        0              1
# 1          Sunday        WEB  Error                        0              1
# 2          Friday        WEB  Error                        0              1
# 3       Wednesday        WEB  Error                        1              1
# 4        Saturday        WEB  Error                        3              3
# ...           ...        ...    ...                      ...            ...
# 178342  Wednesday      PHONE     No                        6              3
# 178343    Tuesday      PHONE     No                        0              0
# 178344    Tuesday      PHONE     No                        0              1
# 178345    Tuesday      PHONE     No                        0              1
# 178346    Tuesday        WEB  Error                        0              0
#
#                HolidayType Accommodationtype DepartureAirport DepartureDate  \
# 0            Cruise + Stay             Hotel       Birmingham    12/14/2018
# 1       Accommodation Only             Villa       London All    10/19/2018
# 2          Package Holiday             Villa        Edinburgh     8/19/2018
# 3             Multi Centre               NaN       Manchester     8/11/2019
# 4          Package Holiday             Hotel          Belfast     7/11/2020
# ...                    ...               ...              ...           ...
# 178342       Cruise + Stay             Hotel       London All     8/16/2017
# 178343     Package Holiday             Villa       Manchester    10/27/2019
# 178344     Package Holiday             Hotel   London Gatwick      8/1/2018
# 178345     Package Holiday              None          Glasgow      7/2/2018
# 178346  Accommodation Only             Hotel      Any Airport     8/15/2017
#
#         Lead.Timeweeks.  ... Children  Infants     TransportType  \
# 0                    30  ...        1        0  Return transfers
# 1                    34  ...        2        0  Return transfers
# 2                    33  ...        1        0  Return transfers
# 3                    28  ...        1        0  Return transfers
# 4                    76  ...        3        0  Return transfers
# ...                 ...  ...      ...      ...               ...
# 178342                0  ...        1        0               NaN
# 178343              115  ...        1        0               NaN
# 178344               50  ...        1        0               NaN
# 178345               46  ...        1        0               NaN
# 178346                0  ...        1        0               NaN
#
#         Answered.Questionnaire  NotesCompleted Title Any.Enquiry.Comments  \
# 0                           NO              NO    Mr                   NO
# 1                           NO              NO    Mr                   NO
# 2                          YES             YES    Mr                   NO
# 3                          YES             YES    Dr                   NO
# 4                           NO              NO    Dr                  YES
# ...                        ...             ...   ...                  ...
# 178342                      NO              NO    Mr                   NO
# 178343                      NO              NO    Mr                   NO
# 178344                      NO              NO    Mr                   NO
# 178345                      NO              NO    Mr                   NO
# 178346                      NO              NO    Mr                   NO
#
#        BookedStatus  year month
# 0                NO  2018     5
# 1                NO  2018     2
# 2                NO  2018     1
# 3                NO  2019     1
# 4                NO  2019     1
# ...             ...   ...   ...
# 178342           NO  2017     8
# 178343           NO  2017     8
# 178344           NO  2017     8
# 178345           NO  2017     8
# 178346           NO  2017     8
#
# [178347 rows x 23 columns]

# %% [markdown]
# # Conditional changes (if web then hotkey is error and numberofconversation is error1)

# %%
data.loc[data['WeborPhone']== "WEB",['Hotkey','NumberofConversationRCD']] = ['Error','Error1']
data
# Out:
#        EnquiryDay WeborPhone Hotkey NumberofConversationRCD  TemplatesSent  \
# 0          Friday        WEB  Error                  Error1              1
# 1          Sunday        WEB  Error                  Error1              1
# 2          Friday        WEB  Error                  Error1              1
# 3       Wednesday        WEB  Error                  Error1              1
# 4        Saturday        WEB  Error                  Error1              3
# ...           ...        ...    ...                     ...            ...
# 178342  Wednesday      PHONE     No                       6              3
# 178343    Tuesday      PHONE     No                       0              0
# 178344    Tuesday      PHONE     No                       0              1
# 178345    Tuesday      PHONE     No                       0              1
# 178346    Tuesday        WEB  Error                  Error1              0
#
#                HolidayType Accommodationtype DepartureAirport DepartureDate  \
# 0            Cruise + Stay             Hotel       Birmingham    12/14/2018
# 1       Accommodation Only             Villa       London All    10/19/2018
# 2          Package Holiday             Villa        Edinburgh     8/19/2018
# 3             Multi Centre               NaN       Manchester     8/11/2019
# 4          Package Holiday             Hotel          Belfast     7/11/2020
# ...                    ...               ...              ...           ...
# 178342       Cruise + Stay             Hotel       London All     8/16/2017
# 178343     Package Holiday             Villa       Manchester    10/27/2019
# 178344     Package Holiday             Hotel   London Gatwick      8/1/2018
# 178345     Package Holiday              None          Glasgow      7/2/2018
# 178346  Accommodation Only             Hotel      Any Airport     8/15/2017
#
#         Lead.Timeweeks.  ... Children  Infants     TransportType  \
# 0                    30  ...        1        0  Return transfers
# 1                    34  ...        2        0  Return transfers
# 2                    33  ...        1        0  Return transfers
# 3                    28  ...        1        0  Return transfers
# 4                    76  ...        3        0  Return transfers
# ...                 ...  ...      ...      ...               ...
# 178342                0  ...        1        0               NaN
# 178343              115  ...        1        0               NaN
# 178344               50  ...        1        0               NaN
# 178345               46  ...        1        0               NaN
# 178346                0  ...        1        0               NaN
#
#         Answered.Questionnaire  NotesCompleted Title Any.Enquiry.Comments  \
# 0                           NO              NO    Mr                   NO
# 1                           NO              NO    Mr                   NO
# 2                          YES             YES    Mr                   NO
# 3                          YES             YES    Dr                   NO
# 4                           NO              NO    Dr                  YES
# ...                        ...             ...   ...                  ...
# 178342                      NO              NO    Mr                   NO
# 178343                      NO              NO    Mr                   NO
# 178344                      NO              NO    Mr                   NO
# 178345                      NO              NO    Mr                   NO
# 178346                      NO              NO    Mr                   NO
#
#        BookedStatus  year month
# 0                NO  2018     5
# 1                NO  2018     2
# 2                NO  2018     1
# 3                NO  2019     1
# 4                NO  2019     1
# ...             ...   ...   ...
# 178342           NO  2017     8
# 178343           NO  2017     8
# 178344           NO  2017     8
# 178345           NO  2017     8
# 178346           NO  2017     8
#
# [178347 rows x 23 columns]

# %% [markdown]
# # Replace numerical variables with median or mode (replace 0 with the median)

# %%
data.Children=data.Children.replace(0,data.Children.median())
data
# Out:
#        EnquiryDay WeborPhone Hotkey  NumberofConversationRCD  TemplatesSent  \
# 0          Friday        WEB     No                        0              1
# 1          Sunday        WEB     No                        0              1
# 2          Friday        WEB     No                        0              1
# 3       Wednesday        WEB    Yes                        1              1
# 4        Saturday        WEB    Yes                        3              3
# ...           ...        ...    ...                      ...            ...
# 178342  Wednesday      PHONE     No                        6              3
# 178343    Tuesday      PHONE     No                        0              0
# 178344    Tuesday      PHONE     No                        0              1
# 178345    Tuesday      PHONE     No                        0              1
# 178346    Tuesday        WEB     No                        0              0
#
#                HolidayType Accommodationtype DepartureAirport DepartureDate  \
# 0            Cruise + Stay             Hotel       Birmingham    12/14/2018
# 1       Accommodation Only             Villa       London All    10/19/2018
# 2          Package Holiday             Villa        Edinburgh     8/19/2018
# 3             Multi Centre               NaN       Manchester     8/11/2019
# 4          Package Holiday             Hotel          Belfast     7/11/2020
# ...                    ...               ...              ...           ...
# 178342       Cruise + Stay             Hotel       London All     8/16/2017
# 178343     Package Holiday             Villa       Manchester    10/27/2019
# 178344     Package Holiday             Hotel   London Gatwick      8/1/2018
# 178345     Package Holiday              None          Glasgow      7/2/2018
# 178346  Accommodation Only             Hotel      Any Airport     8/15/2017
#
#         Lead.Timeweeks.  ... Children  Infants     TransportType  \
# 0                    30  ...        1        0  Return transfers
# 1                    34  ...        2        0  Return transfers
# 2                    33  ...        1        0  Return transfers
# 3                    28  ...        1        0  Return transfers
# 4                    76  ...        3        0  Return transfers
# ...                 ...  ...      ...      ...               ...
# 178342                0  ...        1        0               NaN
# 178343              115  ...        1        0               NaN
# 178344               50  ...        1        0               NaN
# 178345               46  ...        1        0               NaN
# 178346                0  ...        1        0               NaN
#
#         Answered.Questionnaire  NotesCompleted Title Any.Enquiry.Comments  \
# 0                           NO              NO    Mr                   NO
# 1                           NO              NO    Mr                   NO
# 2                          YES             YES    Mr                   NO
# 3                          YES             YES    Dr                   NO
# 4                           NO              NO    Dr                  YES
# ...                        ...             ...   ...                  ...
# 178342                      NO              NO    Mr                   NO
# 178343                      NO              NO    Mr                   NO
# 178344                      NO              NO    Mr                   NO
# 178345                      NO              NO    Mr                   NO
# 178346                      NO              NO    Mr                   NO
#
#        BookedStatus  year month
# 0                NO  2018     5
# 1                NO  2018     2
# 2                NO  2018     1
# 3                NO  2019     1
# 4                NO  2019     1
# ...             ...   ...   ...
# 178342           NO  2017     8
# 178343           NO  2017     8
# 178344           NO  2017     8
# 178345           NO  2017     8
# 178346           NO  2017     8
#
# [178347 rows x 23 columns]

# %% [markdown]
# # Merge two datasets

# %%
# data frame 1
d1 = {'Customer_id':pd.Series([1,2,3,4,5,6]),
  'Product':pd.Series(['Oven','Oven','Oven','Television','Television','Television'])}
df1 = pd.DataFrame(d1)
df1
# Out:
#    Customer_id     Product
# 0            1        Oven
# 1            2        Oven
# 2            3        Oven
# 3            4  Television
# 4            5  Television
# 5            6  Television

# %%
# data frame 2
d2 = {'Customer_id':pd.Series([2,4,6,7,8]),
    'State':pd.Series(['California','California','Texas','New York','Indiana'])}
df2 = pd.DataFrame(d2)
df2
# Out:
#    Customer_id       State
# 0            2  California
# 1            4  California
# 2            6       Texas
# 3            7    New York
# 4            8     Indiana

# %%
#inner join in python pandas (inner,outer,left,right)
 
inner_join_df= pd.merge(df1, df2, on='Customer_id', how='inner')
inner_join_df
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas

# %% [markdown]
# # Saving to CSV

# %%
inner_join_df.to_csv('modified.txt',index=False)
